# %%
import numpy as np
import pandas as pd
import sklearn.metrics as mt
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
#import dataset
df=pd.read_csv("student-mat.csv")
print(df.shape)
df.head()
# Out:
# (395, 33)
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
#sadece 1. ve 2. dönem notlarını aldık
#sdf=df[['G1','G2']]
#df1 = df.iloc[:,0:2] (başka bir yöntem)
#sdf
# Out:
#      G1  G2
# 0     5   6
# 1     5   5
# 2     7   8
# 3    15  14
# 4     6  10
# ..   ..  ..
# 390   9   9
# 391  14  16
# 392  10   8
# 393  11  12
# 394   8   9
#
# [395 rows x 2 columns]

# %%
#normalizasyon için verileri kopyalayalım 1. ve 2. dönem notları için normalizasyon
df_norm=df.copy()
df_norm[['G1','G2']]=preprocessing.minmax_scale(df[['G1','G2']])
#sonuçları görelim
print(df_norm[['G1','G2']].values)
# Out:
# [[0.125      0.31578947]
#  [0.125      0.26315789]
#  [0.25       0.42105263]
#  [0.75       0.73684211]
#  [0.1875     0.52631579]
#  [0.75       0.78947368]
#  [0.5625     0.63157895]
#  [0.1875     0.26315789]
#  [0.8125     0.94736842]
#  [0.6875     0.78947368]
#  [0.4375     0.42105263]
#  [0.4375     0.63157895]
#  [0.6875     0.73684211]
#  [0.4375     0.52631579]
#  [0.6875     0.84210526]
#  [0.6875     0.73684211]
#  [0.625      0.73684211]
#  [0.3125     0.52631579]
#  [0.1875     0.26315789]
#  [0.3125     0.52631579]
#  [0.625      0.73684211]
#  [0.5625     0.78947368]
#  [0.75       0.78947368]
#  [0.625      0.68421053]
#  [0.4375     0.47368421]
#  [0.1875     0.47368421]
#  [0.5625     0.63157895]
#  [0.75       0.84210526]
#  [0.5        0.57894737]
#  [0.4375     0.63157895]
#  [0.375      0.57894737]
#  [0.875      0.84210526]
#  [0.875      0.84210526]
#  [0.3125     0.52631579]
#  [0.5625     0.73684211]
#  [0.3125     0.36842105]
#  [0.75       0.84210526]
# ...

# %%
df_std=df.copy()
st_olcek=preprocessing.StandardScaler()
df_std[['G1','G2']]=st_olcek.fit_transform(df[['G1','G2']])
print(df_std[['G1','G2']].values)
# Out:
# [[-1.78246688 -1.25479105]
#  [-1.78246688 -1.52097927]
#  [-1.1791469  -0.72241461]
#  [ 1.23413302  0.87471471]
#  [-1.48080689 -0.19003817]
#  [ 1.23413302  1.14090293]
#  [ 0.32915305  0.34233827]
#  [-1.48080689 -1.52097927]
#  [ 1.53579301  1.93946759]
#  [ 0.93247303  1.14090293]
#  [-0.27416693 -0.72241461]
#  [-0.27416693  0.34233827]
#  [ 0.93247303  0.87471471]
#  [-0.27416693 -0.19003817]
#  [ 0.93247303  1.40709115]
#  [ 0.93247303  0.87471471]
#  [ 0.63081304  0.87471471]
#  [-0.87748691 -0.19003817]
#  [-1.48080689 -1.52097927]
#  [-0.87748691 -0.19003817]
#  [ 0.63081304  0.87471471]
#  [ 0.32915305  1.14090293]
#  [ 1.23413302  1.14090293]
#  [ 0.63081304  0.60852649]
#  [-0.27416693 -0.45622639]
#  [-1.48080689 -0.45622639]
#  [ 0.32915305  0.34233827]
#  [ 1.23413302  1.40709115]
#  [ 0.02749306  0.07615005]
#  [-0.27416693  0.34233827]
#  [-0.57582692  0.07615005]
#  [ 1.837453    1.40709115]
#  [ 1.837453    1.40709115]
#  [-0.87748691 -0.19003817]
# ...

# %%
#Histogram 
plt.hist(df.G1,bins=12, color='lightblue',label="1. dönem")
plt.xlabel("Notlar")
plt.ylabel("Frekans")
plt.title("1. dönem notları")
plt.show()
plt.hist(df.G2,bins=12, color='violet',label="2. dönem")
plt.xlabel("Notlar")
plt.ylabel("Frekans")
plt.title("2. dönem notları")
plt.show()
